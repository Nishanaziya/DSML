# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanaziya/DSML/blob/master/svm_letter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/letter.csv")
df.head()
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
x = df.drop("letter",axis=1)
x.head()
# Out:
#    xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  x2ybar  \
# 0     2     8      3       5      1     8    13      0      6      6      10
# 1     5    12      3       7      2    10     5      5      4     13       3
# 2     4    11      6       8      6    10     6      2      6     10       3
# 3     7    11      6       6      3     5     9      4      6      4       4
# 4     2     1      3       1      1     8     6      6      6      6       5
#
#    xy2bar  xedge  xedgey  yedge  yedgex
# 0       8      0       8      0       8
# 1       9      2       8      4      10
# 2       7      3       7      3       9
# 3      10      6      10      2       8
# 4       9      1       7      5      10

# %%
y=df["letter"]
y.head()
# Out:
# 0    T
# 1    I
# 2    D
# 3    N
# 4    G
# Name: letter, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC
model = SVC(C=2, kernel="poly")

# %%
model.fit(x_train,y_train)
# Out:
# SVC(C=2, kernel='poly')

# %%
model.score(x_test,y_test)
# Out:
# 0.9575
